# %% [markdown]
# #Data Transformation

# %%
import pandas as pd

# %%
df = pd.read_csv("data1.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# #Sorting & Ranking

# %%
df.sort_values("Year") # ascending sort
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("Year", ascending=False) # descending sort
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_index() #sort by index
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2 = df.sort_values(["Year","IMDb"]).copy() # sort by multiple columns

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# #Reset Index
# If you want the index to start from 0 and be sequential, you can reset it using reset_index()

# %%
df2.reset_index(drop=True, inplace=True) # reset the index and drops the old index

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# #Ranking
#
# The .rank() function in pandas is used to assign ranks to numeric values in a column, like scores or points. By default, it gives the average rank to tied values, which can result in decimal numbers.
#
# For example, if two people share the top score, they both get a rank of 1.5. You can customize the ranking behavior using the method parameter. One useful option is method='dense', which assigns the same rank to ties but doesn’t leave gaps in the ranking sequence.
#
# This is helpful when you want a clean, consecutive ranking system without skips.

# %%
df2["Rank"] = df2["IMDb"].rank(ascending=False,method="dense")

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
# ...

# %% [markdown]
# #Renaming Columns & Index

# %%
df2.rename(columns = {"Actor":"Name"}, inplace=True)

# %%
df2
# Out:
#                   Name                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
# ...

# %%
df2.rename(index = {0:"row1",1:"row2"}, inplace=True)

# %%
df2
# Out:
#                     Name                      Film  Year            Genre  \
# row1          Aamir Khan                    Dangal  2016        Biography
# row2         Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3          Ranveer Singh                 Padmaavat  2018       Historical
# 4          Rajkummar Rao                     Stree  2018    Horror Comedy
# 5     Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6         Hrithik Roshan                       War  2019           Action
# 7           Akshay Kumar                Good Newwz  2019           Comedy
# 8          Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10         Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11        Shah Rukh Khan                   Pathaan  2023           Action
#
# ...

# %%
#To rename all columns:
df2.columns = ["Actor","Movie","year","genre","INR","imdb","rank"]

# %%
df2
# Out:
#                    Actor                     Movie  year            genre  \
# row1          Aamir Khan                    Dangal  2016        Biography
# row2         Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3          Ranveer Singh                 Padmaavat  2018       Historical
# 4          Rajkummar Rao                     Stree  2018    Horror Comedy
# 5     Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6         Hrithik Roshan                       War  2019           Action
# 7           Akshay Kumar                Good Newwz  2019           Comedy
# 8          Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10         Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11        Shah Rukh Khan                   Pathaan  2023           Action
#
# ...

# %% [markdown]
# #Changing Column Order

# %%
df2 = df2[["year","Movie","genre","imdb","rank","INR","Actor"]]

# %%
df2
# Out:
#       year                     Movie            genre  imdb  rank   INR  \
# row1  2016                    Dangal        Biography   8.4   1.0  2024
# row2  2017           Tiger Zinda Hai           Action   6.0   9.0   565
# 2     2017     Badrinath Ki Dulhania  Romantic Comedy   6.1   8.0   201
# 3     2018                 Padmaavat       Historical   7.0   6.0   585
# 4     2018                     Stree    Horror Comedy   7.5   4.0   180
# 5     2018                 Andhadhun         Thriller   8.3   2.0   111
# 6     2019                       War           Action   6.5   7.0   475
# 7     2019                Good Newwz           Comedy   7.0   6.0   318
# 8     2019  Uri: The Surgical Strike           Action   8.2   3.0   342
# 9     2022                Brahmastra          Fantasy   5.6  11.0   431
# 10    2022         Bhool Bhulaiyaa 2    Horror Comedy   5.9  10.0   266
# 11    2023                   Pathaan           Action   7.2   5.0  1050
#
#                    Actor
# ...

# %% [markdown]
# #You can also move one column to the front:

# %%
cols = ["Movie"] + [col for col in df2.columns if col != "Movie"]

# %%
df2 = df2[cols]

# %%
df2
# Out:
#                          Movie  year            genre  imdb  rank   INR  \
# row1                    Dangal  2016        Biography   8.4   1.0  2024
# row2           Tiger Zinda Hai  2017           Action   6.0   9.0   565
# 2        Badrinath Ki Dulhania  2017  Romantic Comedy   6.1   8.0   201
# 3                    Padmaavat  2018       Historical   7.0   6.0   585
# 4                        Stree  2018    Horror Comedy   7.5   4.0   180
# 5                    Andhadhun  2018         Thriller   8.3   2.0   111
# 6                          War  2019           Action   6.5   7.0   475
# 7                   Good Newwz  2019           Comedy   7.0   6.0   318
# 8     Uri: The Surgical Strike  2019           Action   8.2   3.0   342
# 9                   Brahmastra  2022          Fantasy   5.6  11.0   431
# 10           Bhool Bhulaiyaa 2  2022    Horror Comedy   5.9  10.0   266
# 11                     Pathaan  2023           Action   7.2   5.0  1050
#
#                    Actor
# ...
